# %% [markdown]
# <a href="https://colab.research.google.com/github/evellynfurtad0/AulasPA2024/blob/main/ExerciciosFluxograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EXERCÍCIOS SOBRE FLUXOGRAMA**

# %% [markdown]
# **1) Construa um programa que :**
#
# *   Leia a cotação do dólar. **Ex: R\$ 4,50**
# *   Leia o valor que quer converter em dolar **Ex: R\$ 100,00**
# *   Converta esse valor para dolar. **Ex: Resposta: $ 22,22**
# *   Mostre o resultado

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
v_dolar = float(input("Digite a cotação do dólar: "))
v_reais = float(input("Digite a quantidade de reais que você possui: "))
# Out:
# Digite a cotação do dólar: 5.25
# Digite a quantidade de reais que você possui: 250

# %%
v_dolar
# Out:
# 5.25

# %%
v_convertido = v_reais / v_dolar

# %%
print("O valor convertido em dólares é de",v_convertido)
# Out:
# O valor convertido em dólares é de 47.61904761904762

# %%
print("O valor convertido em dólares é de US$",v_convertido)
# Out:
# O valor convertido em dólares é de US$ 47.61904761904762

# %%
print("O valor convertido em dólares é de US$",round(v_convertido,2))
# Out:
# O valor convertido em dólares é de US$ 47.62

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2) Desenvolva um programa que:**
#
# *   Leia 4 (quatro) números. **Ex: 2, 4, 5 e 6**
# *   Calcule o quadrado para cada um. **Ex, resp: 4, 16, 25 e 36.**
# *   Some todos. **Ex. 4+16+25+36**
# *   Mostre o resultado **Ex. Resposta: 81**
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
num1=float(input("Digite o número 1:"))
num2=float(input("Digite o número 2:"))
num3=float(input("Digite o número 3:"))
num4=float(input("Digite o número 4:"))
# Out:
# Digite o número 1:2
# Digite o número 2:4
# Digite o número 3:5
# Digite o número 4:6

# %%
resul=(num1*num1)+(num2*num2)+(num3*num3)+(num4*num4)

# %%
print("A soma dos quadrados é",resul)
# Out:
# A soma dos quadrados é 81.0

# %% [markdown]
# **3) Construa um algoritmo para pagamento de comissão de vendedores de peças, levando-se em consideração que sua comissão será de 5% do total da venda e que você precisará dos seguintes dados:**
#
# *   Preço unitário da peça **Ex: R\$ 2.50**
# *   Quantidade vendida **Ex: 200**
# *   Após isso, calcular a comissão do vendedor e mostrar na tela
# *   Exemplo: **Resposta: R\$ 500,00 de venda e R\$ 25,00 de comissão (5%)**
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
valorprodut=float(input("Digite o valor do produto:"))
quantprodut=float(input("Digite a quantidade do produto:"))
# Out:
# Digite o valor do produto:2.5
# Digite a quantidade do produto:200

# %%
resul=valorprodut*quantprodut

# %%
comissao=resul*5/100

# %%
print("A comissão será de R$", comissao)
# Out:
# A comissão será de R$ 25.0

# %% [markdown]
# **4) O custo ao consumidor de um carro novo é a soma do custo de fábrica com a percentagem do distribuidor e dos impostos (aplicados, primeiro os impostos sobre o custo de fábrica, e depois a percentagem do distribuidor sobre o resultado). Supondo que a percentagem do distribuidor seja de 28% e os impostos 45%. Escrever um algoritmo que leia o custo de fábrica de um carro e informe o custo ao consumidor do mesmo.**
#
# Exemplo:
#
# *   Custo de fábrica do carro: R\$ 25.000,00
# *   Impostos: 45% = R\$ 11.250 (Total R\$ 36.250,00)
# *   Distribuição 28% = R\$ 10.150 (Total R\$ 46.400,00)
# *   Para o consumidor: R\$ 46.400,00
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
custfabric=float(input("Digite o valor da fabricação:"))
# Out:
# Digite o valor da fabricação:25000

# %%
imposto=((custfabric*45)/100)+custfabric

# %%
final=((imposto*28)/100)+imposto

# %%
print("O valor final do carro será de",final)
# Out:
# O valor final do carro será de 46400.0

# %% [markdown]
# **5) Faça um algoritmo que faça conversão de minutos e horas em segundos. Solicite ao usuário a hora e os minutos separado.**
#
# Por exemplo **4h23min** minutos equivale a **4.38h** para fazer cálculos matemáticos
# *   1h = 3600 seg
# *   Qtde em seg = 4.38 * 3600 = 15768 segundos
#
# **Teste de mesa**
# *   3h40min = 3.67h => **13.212 segundos**
# *   1h32min = 1.52h => **5.472 segundos**
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
horas=float(input("Digite as horas:"))
min=float(input("Digite os minutos:"))
# Out:
# Digite as horas:3
# Digite os minutos:40

# %%
resul=((min/60)+horas)

# %%
resul2=(resul*3600)

# %%
print("A conversão de horas para minutos será",resul2)
# Out:
# A conversão de horas para minutos será 13200.0

# %% [markdown]
# **6) Continuando do exercício anterior, um funcionário trabalha em determinada empresa e quer saber quanto irá ganhar de hora extra. Você deverá fazer um algoritmo que solicite quantas horas e quantos minutos ele trabalhou, solicite horas e minutos de forma separada. Depois pergunte quanto ele ganha por hora e informe quanto ele irá ganhar. Sabendo que nessa empresa o funcionário ganha 70% a mais pelas horas trabalhadas.**
#
# *   Ex. Trabalhei neste mês **15h45min** == **15.75h**
# *   Ganho **R\$ 25,00** reais por hora
# *   Resultado tem que ser => **R\$ 669,37** com os **70% a mais**.
# *   Outro teste de mesa: **Se trabalhei 20h, devo ganhar R\$ 850,00**
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
hora=float(input("Digite as horas trabalhadas:"))
min=float(input("Digite os minutos trabalhados:"))
valorporhora=float(input("Digite o valor por hora:"))
# Out:
# Digite as horas trabalhadas:20
# Digite os minutos trabalhados:0
# Digite o valor por hora:25

# %%
horas=((min/60)+hora)

# %%
resul=horas*valorporhora

# %%
resul70=((resul*70)/100)+resul

# %%
print("O valor que você irá receber por hora extra é:",resul, "E com o acréscimo do 70%:",resul70)
# Out:
# O valor que você irá receber por hora extra é: 500.0 E com o acréscimo do 70%: 850.0

# %% [markdown]
# **7) Faça um algoritmo que calcule quanto o usuário irá gastar de gasolina em uma viagem, solicitando os seguinte dados:**
#
# *   Quilômetros a percorrer: Ex. **450km**
# *   Quanto Seu carro consome de Gasolina: Ex. **10km por litro**
# *   Preço Médio da Gasolina: Ex. **R\$ 4,50**
#
# Ao final o sistema deverá responder ao usuário nesse caso que ele gastará em média: **R\$ 202,00 para ida** ou **R\$ 404,00 para ida e volta**.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
km=float(input("Digite quantos quilômetros a percorrer:"))
consome=float(input("Digite quanto o seu carro consome de gasolina:"))
precomed=float(input("Digite o preço médio da gasolina:"))
# Out:
# Digite quantos quilômetros a percorrer:450
# Digite quanto o seu carro consome de gasolina:10
# Digite o preço médio da gasolina:4.5

# %%
resul=(km*precomed)

# %%
resulida=(resul/consome)

# %%
resulidaevolta=resulida+resulida

# %%
print("você gastará de gasolina para ir:", resulida,"e gastará para ir e voltar:",resulidaevolta)
# Out:
# você gastará de gasolina para ir: 202.5 e gastará para ir e voltar: 405.0

# %% [markdown]
# **8) Faça um algoritmo para prever a velocidade média de um carro, sabendo que futuramente esse programa irá  calcular também o valor da multa, se ele tiver acima da velocidade,  para isso solicite os seguintes dados: Obs. A velocidade máxima dessa estrada é 110Km/h.**
#
# *   Qual o percurso percorrido: **Ex. 150km**
# *   Qual o tempo gasto nesse percurso: **Ex. 1h13min**
# *   O Resultado deverá ser: **Velocidade Média foi de 122km/h**
#
# Neste caso o exercício irá parar por aqui, no entanto o assunto das próximas aulas incluirão operadores relacionais, lógicos e condições onde iremos calcular o valor da multa.
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
km=float(input("Digite o percurso percorrido:"))
horas=float(input("Digite as horas percorridas:"))
min=float(input("Digite os minutos percorrido:"))
# Out:
# Digite o percurso percorrido:150
# Digite as horas percorridas:1
# Digite os minutos percorrido:13

# %%
resulhora=(min/60)+horas

# %%
resul=km/resulhora

# %%
print("a velocidade média é:",resul,"km/hr")
# Out:
# a velocidade média é: 123.2876712328767 km/hr
